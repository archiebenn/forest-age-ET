# %%
# random_forest.py - setting up a RF model to predict ET
# Author: Archie Benn
# Date: 12-07-2026

# import libraries
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %%
# set seed for NumPy
np.random.seed(42)

# setup wd 
os.chdir('/home/ab/Dropbox/university/github/bbinf_project')
os.getcwd()
# Out:
# '/home/ab/Dropbox/university/github/bbinf_project'

# %%
# import data
df_10 = pd.read_csv("data/main/10_filtering2/df_10.csv")
df_10.head()
# Out:
#   Site_ID        Date  Latitude  Longitude Continent Cover_type Climate_zone  \
# 0  BE-Bra  2005-01-15  51.30761    4.51984    Europe         MF     Tropical
# 1  BE-Bra  2005-01-16  51.30761    4.51984    Europe         MF     Tropical
# 2  BE-Bra  2005-01-17  51.30761    4.51984    Europe         MF     Tropical
# 3  BE-Bra  2005-01-18  51.30761    4.51984    Europe         MF     Tropical
# 4  BE-Bra  2005-01-19  51.30761    4.51984    Europe         MF     Tropical
#
#    Site_age Age_range        ET       LE  Lai_500m  P_sum_14D  SW_rad   Tair  \
# 0        81    51-100  0.132589  3.83379  0.397561     13.635  42.959  1.163
# 1        81    51-100  0.052709  1.52237  0.386585     12.477  44.886  2.340
# 2        81    51-100  0.064565  1.85631  0.375610     15.243  14.928  7.130
# 3        81    51-100  0.105265  3.03227  0.364634     24.753  16.901  5.133
# 4        81    51-100  0.149545  4.30787  0.353659     23.820  30.965  5.115
#
#    Wspeed    VPD       P       Pa
# ...

# %%
# set features and target
target = df_10['ET']

features_list = ['Tair', 'P_sum_14D', 'SW_rad', 'Wspeed', 'VPD', 'Lai_500m', 'Site_age']
features = df_10[features_list]
# Out:
# 0         0.132589
# 1         0.052709
# 2         0.064565
# 3         0.105265
# 4         0.149545
#             ...
# 166697    0.063745
# 166698    0.079539
# 166699    0.126381
# 166700    0.058237
# 166701    0.135062
# Name: ET, Length: 166702, dtype: float64
